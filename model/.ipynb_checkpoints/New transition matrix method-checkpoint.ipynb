# %%
import numpy as np
import cv2
import random

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

from matplotlib import pyplot

from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import glob
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score

# %%
lim = 600
cover_fnames = sorted(glob.glob('../Cover/*.jpg'))
cover_fnames = cover_fnames[:lim]
juniward_fnames = sorted(glob.glob('../JUNIWARD/*.jpg'))
juniward_fnames = juniward_fnames[:lim]
jmipod_fnames = sorted(glob.glob('../JMiPOD/*.jpg'))
jmipod_fnames = jmipod_fnames[:lim]
uerd_fnames = sorted(glob.glob('../UERD/*.jpg'))
uerd_fnames = uerd_fnames[:lim]

# %%
from helper import *
from jpeg2dct.numpy import load, loads

# %%
T = 4
jump = 3
X_train = []
X_test = []
y_train = []
y_test = []
train_test_split_ = 500

for index, fname in enumerate(cover_fnames):
    img = cv2.imread(fname)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2YCR_CB)
    # get the Y 
    img = img[:,:,0]
    img = img.astype(int)
    Dh_cover, Dv_cover, Dd_cover, Dm_cover = transition_matrix(SPAM_Dh(img, jump, T)+T, T), \
    transition_matrix(SPAM_Dv(img, jump, T)+T, T), transition_matrix(SPAM_Dd(img, jump, jump, T)+T, T), \
    transition_matrix(SPAM_Dd(np.flip(img, axis = 1), jump, jump, T)+T, T)
    hold = np.append(Dh_cover.ravel(), Dv_cover.ravel())
    hold = np.append(hold, Dd_cover.ravel())
    hold = np.append(hold, Dm_cover.ravel())
    
    dct_y, _, _ = load(fname)
    
    dct_img = np.zeros((512, 512))
    for i in range(dct_y.shape[0]):
        for j in range(dct_y.shape[1]):
            dct_img[i*8:(i+1)*8, j*8:(j+1)*8] += dct_y[i][j].reshape(8, 8)
            
    dct_img = dct_img.astype(int)
    
    Dh_cover, Dv_cover, Dd_cover, Dm_cover = transition_matrix(SPAM_Dh(dct_img, jump, T)+T, T), \
    transition_matrix(SPAM_Dv(dct_img, jump, T)+T, T), transition_matrix(SPAM_Dd(dct_img, jump, jump, T)+T, T), \
    transition_matrix(SPAM_Dd(np.flip(dct_img, axis = 1), jump, jump, T)+T, T)
    hold = np.append(hold, Dh_cover.ravel())
    hold = np.append(hold, Dv_cover.ravel())
    hold = np.append(hold, Dd_cover.ravel())
    hold = np.append(hold, Dm_cover.ravel())
    
    if index < train_test_split_:
        X_train.append(hold)
        y_train.append(0)
    else:
        X_test.append(hold)
        y_test.append(0)
    if index%50==0:
        print('i: ', index)
    print(fname)
        
print('Done Covers')

for index, fname in enumerate(uerd_fnames):
    img = cv2.imread(fname)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2YCR_CB)
    # get the Y 
    img = img[:,:,0]
    img = img.astype(int)
    Dh_cover, Dv_cover, Dd_cover, Dm_cover = transition_matrix(SPAM_Dh(img, jump, T)+T, T), \
    transition_matrix(SPAM_Dv(img, jump, T)+T, T), transition_matrix(SPAM_Dd(img, jump, jump, T)+T, T), \
    transition_matrix(SPAM_Dd(np.flip(img, axis = 1), jump, jump, T)+T, T)
    hold = np.append(Dh_cover.ravel(), Dv_cover.ravel())
    hold = np.append(hold, Dd_cover.ravel())
    hold = np.append(hold, Dm_cover.ravel())
    
    dct_y, _, _ = load(fname)
    
    dct_img = np.zeros((512, 512))
    for i in range(dct_y.shape[0]):
        for j in range(dct_y.shape[1]):
            dct_img[i*8:(i+1)*8, j*8:(j+1)*8] += dct_y[i][j].reshape(8, 8)
            
    dct_img = dct_img.astype(int)
    
    Dh_cover, Dv_cover, Dd_cover, Dm_cover = transition_matrix(SPAM_Dh(dct_img, jump, T)+T, T), \
    transition_matrix(SPAM_Dv(dct_img, jump, T)+T, T), transition_matrix(SPAM_Dd(dct_img, jump, jump, T)+T, T), \
    transition_matrix(SPAM_Dd(np.flip(dct_img, axis = 1), jump, jump, T)+T, T)
    hold = np.append(hold, Dh_cover.ravel())
    hold = np.append(hold, Dv_cover.ravel())
    hold = np.append(hold, Dd_cover.ravel())
    hold = np.append(hold, Dm_cover.ravel())
    
    if index < train_test_split_:
        X_train.append(hold)
        y_train.append(1)
    else:
        X_test.append(hold)
        y_test.append(1)
    if index%50==0:
        print(index)
    print(fname)
        
print('Done U')
# Out:
# i:  0
# ../Cover/00001.jpg
# ../Cover/00002.jpg
# ../Cover/00003.jpg
# ../Cover/00004.jpg
# ../Cover/00005.jpg
# ../Cover/00007.jpg
# ../Cover/00008.jpg
# ../Cover/00009.jpg
# ../Cover/00010.jpg
# ../Cover/00011.jpg
# ../Cover/00013.jpg
# ../Cover/00014.jpg
# ../Cover/00015.jpg
# ../Cover/00016.jpg
# ../Cover/00017.jpg
# ../Cover/00018.jpg
# ../Cover/00019.jpg
# ../Cover/00020.jpg
# ../Cover/00021.jpg
# ../Cover/00022.jpg
# ../Cover/00023.jpg
# ../Cover/00024.jpg
# ../Cover/00025.jpg
# ../Cover/00026.jpg
# ../Cover/00027.jpg
# ../Cover/00028.jpg
# ../Cover/00029.jpg
# ../Cover/00030.jpg
# ../Cover/00031.jpg
# ../Cover/00032.jpg
# ../Cover/00033.jpg
# ../Cover/00035.jpg
# ../Cover/00036.jpg
# ../Cover/00037.jpg
# ../Cover/00038.jpg
# ../Cover/00039.jpg
# ../Cover/00040.jpg
# ../Cover/00041.jpg
# ../Cover/00042.jpg
# ../Cover/00043.jpg
# ../Cover/00044.jpg
# ../Cover/00045.jpg
# ../Cover/00046.jpg
# ../Cover/00047.jpg
# ../Cover/00048.jpg
# ../Cover/00050.jpg
# ../Cover/00052.jpg
# ...

# %%
from sklearn.svm import SVC

# %%
X = list(X_train)

# %%
X = [list(x) for x in X_train]

# %%
np.array(X[:501]).shape
# Out:
# (501, 648)

# %%
svclassifier = SVC(kernel='rbf', random_state=42, gamma=10, C=10, degree=3, probability=True)
svclassifier.fit(X, y_train)
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=10, kernel='rbf',
#     max_iter=-1, probability=True, random_state=42, shrinking=True, tol=0.001,
#     verbose=False)

# %%
print(confusion_matrix(y_train, svclassifier.predict(X)))
print(classification_report(y_train, svclassifier.predict(X)))
# Out:
# [[430  70]
#  [156 344]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.86      0.79       500
#            1       0.83      0.69      0.75       500
#
#     accuracy                           0.77      1000
#    macro avg       0.78      0.77      0.77      1000
# weighted avg       0.78      0.77      0.77      1000

# %%
ns_probs = [0 for _ in range(len(y_train))]
# predict probabilities
lr_probs = svclassifier.predict_proba(X)
# keep probabilities for the positive outcome only
lr_probs = lr_probs[:, 1]
# calculate scores
ns_auc = roc_auc_score(y_train, ns_probs)
lr_auc = roc_auc_score(y_train, lr_probs)
# summarize scores
print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('Logistic: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_train, ns_probs)
lr_fpr, lr_tpr, _ = roc_curve(y_train, lr_probs)
# plot the roc curve for the model
pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
pyplot.plot(lr_fpr, lr_tpr, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.116

# %%
y_pred = svclassifier.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5

# %%
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[65 35]
#  [65 35]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.65      0.57       100
#            1       0.50      0.35      0.41       100
#
#     accuracy                           0.50       200
#    macro avg       0.50      0.50      0.49       200
# weighted avg       0.50      0.50      0.49       200

# %%
# hyper_params = {'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
#                      'C': [1, 10, 100, 1000]},
#                     {'kernel': ['linear']}

# results = {}
best_val = -1

for _ in range(20):
    g = random.randint(1, 100)
    c = random.randint(1, 100)
    d = random.randint(1,5)
    print(g, c, d)
    svclassifier = SVC(kernel='rbf', random_state=42, gamma=g, C=c, degree=d, probability=True)
    svclassifier.fit(X, y_train)
    # Predict on the validation set
    y_pred = svclassifier.predict(X_test)
    val_acc = accuracy_score(y_test, y_pred)
    print('Validation accuracy: ', val_acc)

    if val_acc > best_val:
        best_val = val_acc
        best_net = svclassifier
# Out:
# 66 69 5
# Validation accuracy:  0.515
# 90 27 4
# Validation accuracy:  0.52
# 28 2 3
# Validation accuracy:  0.51
# 50 81 5
# Validation accuracy:  0.505
# 61 43 2
# Validation accuracy:  0.51
# 24 64 1
# Validation accuracy:  0.505
# 65 6 5
# Validation accuracy:  0.5
# 98 97 1
# Validation accuracy:  0.51
# 6 70 3
# Validation accuracy:  0.48
# 6 17 4
# Validation accuracy:  0.51
# 38 9 1
# Validation accuracy:  0.51
# 56 91 4
# Validation accuracy:  0.51
# 77 24 5
# Validation accuracy:  0.51
# 91 14 2
# Validation accuracy:  0.51
# 70 4 2
# Validation accuracy:  0.515
# 1 98 1
# Validation accuracy:  0.525
# 32 88 1
# Validation accuracy:  0.5
# 63 25 3
# Validation accuracy:  0.515
# 51 74 5
# Validation accuracy:  0.51
# 39 15 4
# Validation accuracy:  0.515

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=10)
fit = pca.fit(X)
# summarize components
print("Explained Variance: %s" % sum(fit.explained_variance_ratio_))

X_pca = pca.transform(X)
X_test_pca = pca.transform(X_test)

best_val = -1

for _ in range(20):
    g = random.randint(1, 1000)
    c = random.randint(1, 1000)
    d = random.randint(1,5)
    print(g, c, d)
    svclassifier = SVC(kernel='rbf', random_state=42, gamma=g, C=c, degree=d, probability=True)
    svclassifier.fit(X_pca, y_train)
    # Predict on the validation set
    y_pred = svclassifier.predict(X_test_pca)
    val_acc = accuracy_score(y_test, y_pred)
    print('Validation accuracy: ', val_acc)

    if val_acc > best_val:
        best_val = val_acc
        best_net = svclassifier
# Out:
# Explained Variance: 0.9463999571644358
# 792 42 1
# Validation accuracy:  0.52
# 157 253 5
# Validation accuracy:  0.51
# 994 8 3
# Validation accuracy:  0.51
# 201 210 4
# Validation accuracy:  0.505
# 230 765 4
# Validation accuracy:  0.51
# 888 776 2
# Validation accuracy:  0.515
# 656 998 4
# Validation accuracy:  0.51
# 239 701 2
# Validation accuracy:  0.52
# 782 503 4
# Validation accuracy:  0.515
# 960 590 5
# Validation accuracy:  0.51
# 6 641 4
# Validation accuracy:  0.52
# 282 701 2
# Validation accuracy:  0.515
# 871 432 4
# Validation accuracy:  0.515
# 774 844 5
# Validation accuracy:  0.515
# 169 664 3
# Validation accuracy:  0.515
# 931 300 4
# Validation accuracy:  0.515
# 834 218 3
# Validation accuracy:  0.52
# 968 379 4
# Validation accuracy:  0.51
# 560 851 2
# Validation accuracy:  0.51
# 346 204 5
# Validation accuracy:  0.515

# %%
pca = PCA(n_components=10)
fit = pca.fit(X)
# summarize components
print("Explained Variance: %s" % sum(fit.explained_variance_ratio_))

X_pca = pca.transform(X)
svclassifier = SVC(kernel='rbf', random_state=42, gamma=10, C=20, degree=4, probability=True)
svclassifier.fit(X_pca, y_train)

print(confusion_matrix(y_train, svclassifier.predict(X_pca)))
print(classification_report(y_train, svclassifier.predict(X_pca)))
# Out:
# Explained Variance: 0.9608290064408065
# [[328 172]
#  [262 238]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.66      0.60       500
#            1       0.58      0.48      0.52       500
#
#     accuracy                           0.57      1000
#    macro avg       0.57      0.57      0.56      1000
# weighted avg       0.57      0.57      0.56      1000

# %%
X_test_pca = pca.transform(X_test)
y_pred = svclassifier.predict(X_test_pca)

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[56 44]
#  [52 48]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.56      0.54       100
#            1       0.52      0.48      0.50       100
#
#     accuracy                           0.52       200
#    macro avg       0.52      0.52      0.52       200
# weighted avg       0.52      0.52      0.52       200
